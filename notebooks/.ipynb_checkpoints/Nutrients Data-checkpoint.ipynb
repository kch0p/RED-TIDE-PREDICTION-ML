# %%
import pandas as pd
import numpy as np
import os
from glob import glob
import sys
import warnings
from time import time

# %%
cd
# Out:
# /Users/karatechop

# %%
cd /Users/karatechop/Library/CloudStorage/GoogleDrive-kc1558628@berkeley.edu/My Drive/ENERES 131 FINAL PROJECT (1)/data
# Out:
# /Users/karatechop/Library/CloudStorage/GoogleDrive-kc1558628@berkeley.edu/My Drive/ENERES 131 FINAL PROJECT (1)/data

# %%
ls
# Out:
# 2008_2022_HAB_nutrients_scripps - data.csv
# 2008_2022_HAB_nutrients_scripps.gsheet
# buoy/
# original 100 year scripps temp data/
# recent scripps_TEMP_2005-2020 from 100 year.csv

# %%
nutrients = pd.read_html('https://erddap.sccoos.org/erddap/tabledap/HABs-ScrippsPier.htmlTable?Location_Code%2Clatitude%2Clongitude%2Cdepth%2CSampleID%2Ctime%2CTemp%2CAir_Temp%2CSalinity%2CChl_Volume_Filtered%2CChl1%2CChl2%2CAvg_Chloro%2CPhaeo1%2CPhaeo2%2CAvg_Phaeo%2CPhosphate%2CSilicate%2CNitrite%2CNitrite_Nitrate%2CAmmonium%2CNitrate%2CDA_Volume_Filtered%2CpDA%2CtDA%2CdDA%2CVolume_Settled_for_Counting%2CAkashiwo_sanguinea%2CAlexandrium_spp%2CDinophysis_spp%2CLingulodinium_polyedra%2CProrocentrum_spp%2CPseudo_nitzschia_delicatissima_group%2CPseudo_nitzschia_seriata_group%2CCeratium_spp%2CCochlodinium_spp%2CGymnodinium_spp%2COther_Diatoms%2COther_Dinoflagellates%2CTotal_Phytoplankton&time%3E=2008-01-24T00%3A00%3A00Z&time%3C=2022-10-31T17%3A43%3A00Z')[1]
nutrients = nutrients[nutrients.columns[1:]]

# %%
nutrients['hab_RT_status','categorical 0/1'] = 0
nutrients.loc[(nutrients['Chl1',              'mg/m3']>nutrients['Chl1',              'mg/m3'].quantile(0.95)) | 
              (nutrients['Chl2',              'mg/m3']>nutrients['Chl2',              'mg/m3'].quantile(0.95)) | 
              (nutrients['Avg_Chloro',              'mg/m3']>nutrients['Avg_Chloro',              'mg/m3'].quantile(0.95)),('hab_RT_status', 'categorical 0/1')]=1

nutrients['hab_RT_status','categorical 0/1'].value_counts()
# Out:
# 0    709
# 1     40
# Name: (hab_RT_status, categorical 0/1), dtype: int64

# %%
nutrients
# Out:
#          latitude    longitude depth           SampleID                  time  \
#     degrees_north degrees_east     m Unnamed: 4_level_1                   UTC
# 0          32.867     -117.257   NaN           20080630  2008-06-30T15:00:00Z
# 1          32.867     -117.257   NaN           20080707  2008-07-07T15:00:00Z
# 2          32.867     -117.257   NaN           20080714  2008-07-14T14:54:00Z
# 3          32.867     -117.257   NaN           20080721  2008-07-21T14:50:00Z
# 4          32.867     -117.257   NaN           20080728  2008-07-28T16:44:00Z
# ..            ...          ...   ...                ...                   ...
# 744        32.867     -117.257   NaN           20221003  2022-10-03T19:02:00Z
# 745        32.867     -117.257   NaN           20221010  2022-10-10T18:53:00Z
# 746        32.867     -117.257   NaN           20221017  2022-10-17T19:01:00Z
# 747        32.867     -117.257   NaN           20221024  2022-10-24T18:43:00Z
# 748        32.867     -117.257   NaN           20221031  2022-10-31T17:43:00Z
#
#         Temp Air_Temp           Salinity Chl_Volume_Filtered   Chl1  ...  \
#     degree_C degree_C Unnamed: 8_level_1                  mL  mg/m3  ...
# 0       19.8      NaN                NaN               100.0   1.81  ...
# 1       17.3      NaN                NaN               100.0   2.68  ...
# 2       21.7      NaN                NaN               100.0   0.99  ...
# 3       20.2      NaN                NaN               100.0   1.21  ...
# 4       22.4      NaN                NaN               100.0   2.37  ...
# ..       ...      ...                ...                 ...    ...  ...
# 744     19.8      NaN                NaN               100.0   6.83  ...
# 745     20.3      NaN                NaN               100.0  10.80  ...
# 746     20.2      NaN                NaN               100.0  14.00  ...
# 747     20.4      NaN                NaN               100.0   1.22  ...
# 748     19.8      NaN                NaN               100.0   2.34  ...
#
#     Prorocentrum_spp Pseudo_nitzschia_delicatissima_group  \
#              cells/L                              cells/L
# 0                NaN                                  NaN
# 1                NaN                                  NaN
# 2                NaN                                  NaN
# 3                NaN                                  NaN
# 4                NaN                                  NaN
# ..               ...                                  ...
# 744          35045.0                               5632.0
# 745          71341.0                              11264.0
# 746          91367.0                               4381.0
# 747          12516.0                               3755.0
# 748          41928.0                                626.0
#
#     Pseudo_nitzschia_seriata_group Ceratium_spp Cochlodinium_spp  \
#                            cells/L      cells/L          cells/L
# 0                              NaN          NaN              NaN
# 1                              NaN          NaN              NaN
# 2                              NaN          NaN              NaN
# 3                              NaN          NaN              NaN
# 4                              NaN          NaN              NaN
# ..                             ...          ...              ...
# 744                            0.0       3755.0           1877.0
# 745                            0.0      28787.0           1877.0
# 746                            0.0      55697.0          14394.0
# 747                         1877.0      12516.0           3129.0
# 748                            0.0      13768.0           6884.0
#
#     Gymnodinium_spp Other_Diatoms Other_Dinoflagellates Total_Phytoplankton  \
#             cells/L       cells/L               cells/L             cells/L
# 0               NaN           NaN                   NaN                 NaN
# 1               NaN           NaN                   NaN                 NaN
# 2               NaN           NaN                   NaN                 NaN
# 3               NaN           NaN                   NaN                 NaN
# 4               NaN           NaN                   NaN                 NaN
# ..              ...           ...                   ...                 ...
# 744           626.0      108264.0               39425.0            239056.0
# 745          5632.0      148315.0              146438.0            456209.0
# 746         21277.0       90115.0              367344.0            657092.0
# 747          3129.0       22529.0               34419.0             93870.0
# 748         10639.0       36922.0              160830.0            280985.0
#
#       hab_RT_status
#     categorical 0/1
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 744               1
# 745               1
# 746               1
# 747               0
# 748               0
#
# [749 rows x 40 columns]

# %%
nutrients.isna().sum()
# Out:
# latitude                              degrees_north           0
# longitude                             degrees_east            0
# depth                                 m                     749
# SampleID                              Unnamed: 4_level_1      0
# time                                  UTC                     0
# Temp                                  degree_C                0
# Air_Temp                              degree_C              749
# Salinity                              Unnamed: 8_level_1    749
# Chl_Volume_Filtered                   mL                      9
# Chl1                                  mg/m3                  10
# Chl2                                  mg/m3                  11
# Avg_Chloro                            mg/m3                  10
# Phaeo1                                mg/m3                  10
# Phaeo2                                mg/m3                  11
# Avg_Phaeo                             mg/m3                  10
# Phosphate                             uM                     26
# Silicate                              uM                     26
# Nitrite                               uM                     26
# Nitrite_Nitrate                       uM                    749
# Ammonium                              uM                     26
# Nitrate                               uM                     26
# DA_Volume_Filtered                    mL                     20
# pDA                                   ng/mL                  20
# tDA                                   ng/mL                 749
# dDA                                   ng/mL                 749
# Volume_Settled_for_Counting           mL                    749
# Akashiwo_sanguinea                    cells/L               580
# Alexandrium_spp                       cells/L               580
# Dinophysis_spp                        cells/L               580
# Lingulodinium_polyedra                cells/L               580
# Prorocentrum_spp                      cells/L               580
# Pseudo_nitzschia_delicatissima_group  cells/L               580
# Pseudo_nitzschia_seriata_group        cells/L               580
# Ceratium_spp                          cells/L               580
# Cochlodinium_spp                      cells/L               580
# Gymnodinium_spp                       cells/L               580
# Other_Diatoms                         cells/L               580
# Other_Dinoflagellates                 cells/L               580
# Total_Phytoplankton                   cells/L               580
# hab_RT_status                         categorical 0/1         0
# dtype: int64

# %%
nutrients_simplified = nutrients[['time','Temp',
                                  'Chl1','Chl2','Avg_Chloro',
                                  'Phaeo1','Phaeo2','Avg_Phaeo',
                                  'Phosphate',
                                  'Silicate',
                                  'Nitrite',
                                  'Ammonium',
                                  'Total_Phytoplankton',
                                  'hab_RT_status']]
nutrients_simplified
# Out:
#                      time     Temp   Chl1   Chl2 Avg_Chloro Phaeo1 Phaeo2  \
#                       UTC degree_C  mg/m3  mg/m3      mg/m3  mg/m3  mg/m3
# 0    2008-06-30T15:00:00Z     19.8   1.81   1.83       1.82   0.59   0.61
# 1    2008-07-07T15:00:00Z     17.3   2.68   2.73       2.71   1.24   1.12
# 2    2008-07-14T14:54:00Z     21.7   0.99   1.00       0.99   0.55   0.54
# 3    2008-07-21T14:50:00Z     20.2   1.21   1.24       1.23   0.49   0.48
# 4    2008-07-28T16:44:00Z     22.4   2.37   2.44       2.41   0.41   0.36
# ..                    ...      ...    ...    ...        ...    ...    ...
# 744  2022-10-03T19:02:00Z     19.8   6.83   6.86       6.84   0.58   0.56
# 745  2022-10-10T18:53:00Z     20.3  10.80  10.80      10.80   1.11   1.14
# 746  2022-10-17T19:01:00Z     20.2  14.00  14.06      14.03   1.83   2.69
# 747  2022-10-24T18:43:00Z     20.4   1.22   1.25       1.24   0.25   0.23
# 748  2022-10-31T17:43:00Z     19.8   2.34   2.33       2.34   0.63   0.60
#
#     Avg_Phaeo Phosphate Silicate Nitrite Ammonium Total_Phytoplankton  \
#         mg/m3        uM       uM      uM       uM             cells/L
# 0        0.60      0.24      5.6    0.03     0.53                 NaN
# 1        1.18      0.37      5.1    0.04     1.06                 NaN
# 2        0.55      0.24      3.5    0.00     0.35                 NaN
# 3        0.48      0.17      4.2    0.00     0.55                 NaN
# 4        0.39      0.12      3.8    0.00     0.62                 NaN
# ..        ...       ...      ...     ...      ...                 ...
# 744      0.57       NaN      NaN     NaN      NaN            239056.0
# 745      1.12       NaN      NaN     NaN      NaN            456209.0
# 746      2.26       NaN      NaN     NaN      NaN            657092.0
# 747      0.24       NaN      NaN     NaN      NaN             93870.0
# 748      0.62       NaN      NaN     NaN      NaN            280985.0
#
#       hab_RT_status
#     categorical 0/1
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 744               1
# 745               1
# 746               1
# 747               0
# 748               0
#
# [749 rows x 14 columns]

# %%
nutrients_simplified.to_csv('nutrients_simplified(UNITS).csv',index=False)
# nutrients_simplified.droplevel(1,axis=1).to_csv('nutrients_simplified(NO_units).csv',index=False)
